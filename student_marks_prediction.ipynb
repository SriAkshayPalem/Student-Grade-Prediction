# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\COMP1\Downloads\student_info.csv")

# %%
data
# Out:
#      study_hours  student_marks
# 0           6.83          78.50
# 1           6.56          76.74
# 2            NaN          78.68
# 3           5.67          71.82
# 4           8.67          84.19
# ..           ...            ...
# 195         7.53          81.67
# 196         8.56          84.68
# 197         8.94          86.75
# 198         6.60          78.05
# 199         8.35          83.50
#
# [200 rows x 2 columns]

# %%
data.head()
# Out:
#    study_hours  student_marks
# 0         6.83          78.50
# 1         6.56          76.74
# 2          NaN          78.68
# 3         5.67          71.82
# 4         8.67          84.19

# %%
data.tail()
# Out:
#      study_hours  student_marks
# 195         7.53          81.67
# 196         8.56          84.68
# 197         8.94          86.75
# 198         6.60          78.05
# 199         8.35          83.50

# %%
data.shape
# Out:
# (200, 2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   study_hours    195 non-null    float64
#  1   student_marks  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
data.describe()
# Out:
#        study_hours  student_marks
# count   195.000000      200.00000
# mean      6.995949       77.93375
# std       1.253060        4.92570
# min       5.010000       68.57000
# 25%       5.775000       73.38500
# 50%       7.120000       77.71000
# 75%       8.085000       82.32000
# max       8.990000       86.99000

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=data.study_hours,y=data.student_marks,color="Black")
plt.xlabel("study_hours")
plt.ylabel("student_marks")
plt.title("studyhours Vs studentmarks")
plt.show()

# %%
data.isnull()
# Out:
#      study_hours  student_marks
# 0          False          False
# 1          False          False
# 2           True          False
# 3          False          False
# 4          False          False
# ..           ...            ...
# 195        False          False
# 196        False          False
# 197        False          False
# 198        False          False
# 199        False          False
#
# [200 rows x 2 columns]

# %%
data.isnull().any()
# Out:
# study_hours       True
# student_marks    False
# dtype: bool

# %%
data.mean()
# Out:
# study_hours       6.995949
# student_marks    77.933750
# dtype: float64

# %%
data1 =data.fillna(data.mean())

# %%
data1.isnull().sum()
# Out:
# study_hours      0
# student_marks    0
# dtype: int64

# %%
plt.figure(figsize=(5,5))
sns.heatmap(data.corr(),annot=False,linewidths=2)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.barplot(x="study_hours", y="student_marks", data=data1,palette=["blue", "yellow", "green"])
plt.show()
# Out:
# C:\Users\COMP1\AppData\Local\Temp\ipykernel_10176\3435864494.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="study_hours", y="student_marks", data=data1,palette=["blue", "yellow", "green"])
# C:\Users\COMP1\AppData\Local\Temp\ipykernel_10176\3435864494.py:2: UserWarning:
# The palette list has fewer values (3) than needed (145) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x="study_hours", y="student_marks", data=data1,palette=["blue", "yellow", "green"])

# %%
#split dataset
#matrix = X = Independent Variable = student_hours
#vector = y = Dependent Variable = student_marks 
X=data1.drop("student_marks",axis="columns")
y=data1.drop("study_hours",axis="columns")
print("shape of X =",X.shape)
print("shape of y =",y.shape)
# Out:
# shape of X = (200, 1)
# shape of y = (200, 1)

# %%
sns.set_palette(["yellow"])
sns.pairplot(data1)

# %%
# !pip install scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2,random_state=51) # taking 20% data for test and another 20% is randomly
print("shape of X_train =",X_train.shape)
print("shape of y_train =",y_train.shape)
print("shape of X_test =",X_test.shape)
print("shape of y_test =",y_test.shape)
# Out:
# shape of X_train = (160, 1)
# shape of y_train = (160, 1)
# shape of X_test = (40, 1)
# shape of y_test = (40, 1)

# %%
from sklearn.linear_model import LinearRegression #linearRegression y=m*x+c
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_#To know value of m
# Out:
# array([[3.93571802]])

# %%
lr.intercept_ #To know value of c
# Out:
# array([50.44735504])

# %%
m=3.93571802
c=50.44735504
y=m*3+c #Given x value as 3
y
# Out:
# 62.2545091

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([[83.11381458],
#        [78.9025963 ],
#        [84.57003024],
#        [85.82946001],
#        [84.72745896],
#        [80.75238377],
#        [72.84159055],
#        [71.66087515],
#        [73.23516235],
#        [71.66087515],
#        [73.47130543],
#        [76.38373677],
#        [73.23516235],
#        [73.58937697],
#        [82.95638585],
#        [70.40144538],
#        [73.23516235],
#        [78.74516758],
#        [75.55723598],
#        [82.68088559],
#        [76.65923703],
#        [70.48015974],
#        [74.77009238],
#        [77.98143645],
#        [85.59331693],
#        [82.56281405],
#        [76.42309395],
#        [85.0423164 ],
#        [78.39095296],
#        [81.38209865],
#        [81.73631327],
#        [83.15317176],
#        [82.20859943],
#        [81.10659839],
#        [73.58937697],
#        [71.1492318 ],
#        [71.89701823],
#        [81.53952737],
#        [72.60544747],
#        [71.93637541]])

# %%
pd.DataFrame(np.c_[X_test,y_test,y_pred],columns=["study_hours","student_marks_original Percentage","student_marks_predicted Percentage"])
    #Converting this into dataframe to do data analysis
# Out:
#     study_hours  student_marks_original Percentage  \
# 0      8.300000                              82.02
# 1      7.230000                              77.55
# 2      8.670000                              84.19
# 3      8.990000                              85.46
# 4      8.710000                              84.03
# 5      7.700000                              80.81
# 6      5.690000                              73.61
# 7      5.390000                              70.90
# 8      5.790000                              73.14
# 9      5.390000                              73.02
# 10     5.850000                              75.02
# 11     6.590000                              75.37
# 12     5.790000                              74.44
# 13     5.880000                              73.40
# 14     8.260000                              81.70
# 15     5.070000                              69.27
# 16     5.790000                              73.64
# ...

# %%
lr.score(X_test,y_test) #to check accuracy of prediction model
# Out:
# 0.9514124242154464

# %%
plt.scatter(X_train,y_train)

# %%
plt.figure(figsize=(7,5))
plt.scatter(X_test,y_test)
plt.plot(X_train,lr.predict(X_train),color="blue")
